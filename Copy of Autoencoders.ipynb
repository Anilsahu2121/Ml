# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 199  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=12,
                batch_size=144,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/12
# 417/417 [==============================] - 6s 14ms/step - loss: 0.6964 - val_loss: 0.6958
# Epoch 2/12
# 417/417 [==============================] - 5s 13ms/step - loss: 0.6951 - val_loss: 0.6945
# Epoch 3/12
# 417/417 [==============================] - 5s 12ms/step - loss: 0.6939 - val_loss: 0.6933
# Epoch 4/12
# 417/417 [==============================] - 6s 15ms/step - loss: 0.6927 - val_loss: 0.6921
# Epoch 5/12
# 417/417 [==============================] - 5s 12ms/step - loss: 0.6915 - val_loss: 0.6909
# Epoch 6/12
# 417/417 [==============================] - 6s 15ms/step - loss: 0.6904 - val_loss: 0.6897
# Epoch 7/12
# 417/417 [==============================] - 6s 13ms/step - loss: 0.6892 - val_loss: 0.6885
# Epoch 8/12
# 417/417 [==============================] - 6s 14ms/step - loss: 0.6880 - val_loss: 0.6873
# Epoch 9/12
# 417/417 [==============================] - 5s 12ms/step - loss: 0.6868 - val_loss: 0.6861
# Epoch 10/12
# 417/417 [==============================] - 5s 13ms/step - loss: 0.6856 - val_loss: 0.6849
# Epoch 11/12
# 417/417 [==============================] - 6s 14ms/step - loss: 0.6844 - val_loss: 0.6837
# Epoch 12/12
# 417/417 [==============================] - 5s 12ms/step - loss: 0.6831 - val_loss: 0.6824

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of the encoded representation
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoding layers
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoding layers
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Encoder model
encoder = Model(input_img, encoded)

# Decoder model
encoded_input = Input(shape=(encoding_dim,))
decoder_layer1 = autoencoder.layers[-3]
decoder_layer2 = autoencoder.layers[-2]
decoder_layer3 = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer3(decoder_layer2(decoder_layer1(encoded_input))))

# %%
# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 6s 20ms/step - loss: 0.2394 - val_loss: 0.1586
# Epoch 2/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1441 - val_loss: 0.1327
# Epoch 3/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1284 - val_loss: 0.1218
# Epoch 4/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1190 - val_loss: 0.1138
# Epoch 5/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1121 - val_loss: 0.1082
# Epoch 6/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1079 - val_loss: 0.1048
# Epoch 7/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1051 - val_loss: 0.1026
# Epoch 8/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.1027 - val_loss: 0.1004
# Epoch 9/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1008 - val_loss: 0.0988
# Epoch 10/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0992 - val_loss: 0.0973
# Epoch 11/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0979 - val_loss: 0.0967
# Epoch 12/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0965 - val_loss: 0.0947
# Epoch 13/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0953 - val_loss: 0.0936
# Epoch 14/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0940 - val_loss: 0.0925
# Epoch 15/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 16/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0924 - val_loss: 0.0910
# Epoch 17/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0917 - val_loss: 0.0908
# Epoch 18/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0911 - val_loss: 0.0898
# Epoch 19/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0905 - val_loss: 0.0895
# Epoch 20/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0900 - val_loss: 0.0888
# Epoch 21/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0895 - val_loss: 0.0882
# Epoch 22/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0891 - val_loss: 0.0881
# Epoch 23/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0888 - val_loss: 0.0879
# Epoch 24/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0883 - val_loss: 0.0878
# Epoch 25/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 26/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0877 - val_loss: 0.0867
# Epoch 27/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 28/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0871 - val_loss: 0.0863
# Epoch 29/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0867 - val_loss: 0.0859
# Epoch 30/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0864 - val_loss: 0.0856
# Epoch 31/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0862 - val_loss: 0.0853
# Epoch 32/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 33/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0855 - val_loss: 0.0848
# Epoch 34/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0853 - val_loss: 0.0846
# Epoch 35/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0850 - val_loss: 0.0845
# Epoch 36/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0848 - val_loss: 0.0840
# Epoch 37/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0846 - val_loss: 0.0841
# Epoch 38/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0843 - val_loss: 0.0836
# Epoch 39/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 40/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0840 - val_loss: 0.0836
# Epoch 41/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0838 - val_loss: 0.0831
# Epoch 42/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0836 - val_loss: 0.0829
# Epoch 43/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0835 - val_loss: 0.0829
# Epoch 44/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0832 - val_loss: 0.0830
# Epoch 45/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0831 - val_loss: 0.0824
# Epoch 46/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0829 - val_loss: 0.0824
# Epoch 47/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0828 - val_loss: 0.0824
# Epoch 48/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0827 - val_loss: 0.0822
# Epoch 49/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0825 - val_loss: 0.0822
# Epoch 50/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0824 - val_loss: 0.0819

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
